# %% [markdown]
# Число ссылок на элемент

# %%
import sys
a = []
b = a
sys.getrefcount(a)
# Out:
# 3

# %%
import sys
a = 6
b = a
sys.getrefcount(a)
# Out:
# 347

# %%
import sys
sys.getrefcount(a)
# Out:
# 346

# %%
a = 5
b =10 -5
c = 13-8
id(a)==id(b)==id(c)
# Out:
# True

# %% [markdown]
# Проблема заключалась в том, что эта переменная счетчика ссылок нуждалась в защите от условий гонки, когда два потока одновременно увеличивают или уменьшают ее значение. Если это произойдет, это может привести либо к утечке памяти, которая никогда не будет освобождена, либо, что еще хуже, к неправильному освобождению памяти, когда ссылка на этот объект все еще существует. Это может привести к сбоям или другим «странным» ошибкам в ваших программах на Python.
#
# Эту переменную счетчика ссылок можно защитить, добавив блокировки ко всем структурам данных, которые совместно используются потоками, чтобы они не изменялись несогласованно.
#
# Но добавление блокировки к каждому объекту или группе объектов означает, что будет существовать несколько блокировок, что может вызвать другую проблему — взаимные блокировки (взаимные блокировки могут возникнуть только при наличии более одной блокировки). Другим побочным эффектом будет снижение производительности, вызванное повторным получением и освобождением блокировок.
#
# GIL — это единая блокировка самого интерпретатора, которая добавляет правило, согласно которому выполнение любого байт-кода Python требует получения блокировки интерпретатора. Это предотвращает взаимоблокировки (поскольку существует только одна блокировка) и не приводит к значительным потерям производительности. Но это эффективно делает любую программу Python, привязанную к процессору, однопоточной.
#
# GIL, хотя и используется интерпретаторами для других языков, таких как Ruby, не является единственным решением этой проблемы. Некоторые языки избегают требования GIL для потокобезопасного управления памятью, используя подходы, отличные от подсчета ссылок, такие как сборка мусора.
#
# С другой стороны, это означает, что эти языки часто должны компенсировать потерю однопоточного преимущества производительности GIL, добавляя другие функции повышения производительности, такие как JIT-компиляторы.

# %% [markdown]
# ## Почему GIL был выбран в качестве решения?
# Итак, почему подход, который кажется таким мешающим, используется в Python? Было ли это плохим решением разработчиков Python?
#
# Что ж, по словам Ларри Гастингса , дизайнерское решение GIL — одна из вещей, которые сделали Python таким популярным, как сегодня.
#
# Python существует с тех пор, когда операционные системы не имели концепции потоков. Python был разработан, чтобы быть простым в использовании, чтобы ускорить разработку, и все больше и больше разработчиков начали его использовать.
#
# Было написано множество расширений для существующих библиотек C, функции которых были необходимы в Python. Чтобы предотвратить несогласованные изменения, эти расширения C требовали многопоточного управления памятью, которое обеспечивал GIL.
#
# GIL прост в реализации и легко добавляется в Python. Это обеспечивает повышение производительности однопоточных программ, поскольку необходимо управлять только одной блокировкой.
#
# Библиотеки C, которые не были потокобезопасными, стало легче интегрировать. И эти расширения C стали одной из причин, по которой Python был с готовностью принят различными сообществами.
#
# Как видите, GIL был прагматичным решением сложной проблемы, с которой разработчики CPython столкнулись на заре существования Python.

# %% [markdown]
# ---

# %%
import time
from threading import Thread

COUNT = 50000000

def countdown(n):
    while n>0:
        n -= 1

start = time.time()
countdown(COUNT)
end = time.time()

print('Time taken in seconds -', end - start)
# Out:
# Time taken in seconds - 2.3810031414031982

# %%
import time
from threading import Thread

COUNT = 50000000

def countdown(n):
    while n>0:
        n -= 1
#         if n < 3:
#             print("n < 3")

t1 = Thread(target=countdown, args=(COUNT//2,))
t2 = Thread(target=countdown, args=(COUNT//2,))



start = time.time()
t1.start()
t2.start()
t1.join()
t2.join()


end = time.time()

print('Time taken in seconds -', end - start)
# Out:
# Time taken in seconds - 2.329993963241577

# %% [markdown]
# Как видите, обе версии занимают почти одинаковое количество времени. В многопоточной версии GIL предотвращал параллельное выполнение потоков, привязанных к ЦП.
#
# GIL не оказывает большого влияния на производительность многопоточных программ, связанных с вводом-выводом, поскольку блокировка распределяется между потоками, пока они ожидают ввода-вывода.
#
# Но программа, потоки которой полностью привязаны к процессору, например, программа, которая обрабатывает изображение по частям с использованием потоков, не только станет однопоточной из-за блокировки, но также увидит увеличение времени выполнения, как показано в приведенном выше примере. , по сравнению со сценарием, в котором он был написан полностью однопоточным.
#
# Это увеличение является результатом накладных расходов на получение и освобождение, добавленных блокировкой.

# %% [markdown]
# ## Почему GIL еще не удален?
# Разработчики Python получают много жалоб по этому поводу, но такой популярный язык, как Python, не может внести столь значительные изменения, как удаление GIL, без проблем с обратной несовместимостью.
#
# Очевидно, что GIL можно удалить, и это неоднократно делалось разработчиками и исследователями в прошлом, но все эти попытки нарушили существующие расширения C, которые сильно зависят от решения, предоставляемого GIL.
#
# Конечно, есть и другие решения проблемы, которую решает GIL, но некоторые из них снижают производительность однопоточных и многопоточных программ, связанных с вводом-выводом, а некоторые просто слишком сложны. В конце концов, вы бы не хотели, чтобы ваши существующие программы на Python работали медленнее после выхода новой версии, верно?
#
# Создатель и BDFL Python Гвидо ван Россум дал ответ сообществу в сентябре 2007 года в своей статье «Удалить GIL непросто» :
# ```
# «Я бы приветствовал набор исправлений в Py3k только в том случае, если производительность для однопоточной программы (и для многопоточной, но связанной с вводом-выводом программы) не снизится »
# ```
#
# И это условие не было выполнено ни одной из предпринятых с тех пор попыток.

# %%
from multiprocessing import Pool
import time

COUNT = 50000000
def countdown(n):
    while n>0:
        n -= 1

if __name__ == '__main__':
    pool = Pool(processes=2)
    start = time.time()
    r1 = pool.apply_async(countdown, [COUNT//2])
    r2 = pool.apply_async(countdown, [COUNT//2])
    pool.close()
    pool.join()
    end = time.time()
    print('Time taken in seconds -', end - start)

# %% [markdown]
# ---

# %%
import time
import requests
import concurrent.futures


def get_wiki_page_existence(wiki_page_url, timeout=10):
    response = requests.get(url=wiki_page_url, timeout=timeout)

    page_status = "unknown"
    if response.status_code == 200:
        page_status = "exists"
    elif response.status_code == 404:
        page_status = "does not exist"

    return wiki_page_url + " - " + page_status

wiki_page_urls = ["https://en.wikipedia.org/wiki/" + str(i) for i in range(50)]

print("Running without threads:")
without_threads_start = time.time()
for url in wiki_page_urls:
    print(get_wiki_page_existence(wiki_page_url=url))
print("Without threads time:", time.time() - without_threads_start)
# Out:
# Running without threads:
# https://en.wikipedia.org/wiki/0 - exists
# https://en.wikipedia.org/wiki/1 - exists
# https://en.wikipedia.org/wiki/2 - exists
# https://en.wikipedia.org/wiki/3 - exists
# https://en.wikipedia.org/wiki/4 - exists
# https://en.wikipedia.org/wiki/5 - exists
# https://en.wikipedia.org/wiki/6 - exists
# https://en.wikipedia.org/wiki/7 - exists
# https://en.wikipedia.org/wiki/8 - exists
# https://en.wikipedia.org/wiki/9 - exists
# https://en.wikipedia.org/wiki/10 - exists
# https://en.wikipedia.org/wiki/11 - exists
# https://en.wikipedia.org/wiki/12 - exists
# https://en.wikipedia.org/wiki/13 - exists
# https://en.wikipedia.org/wiki/14 - exists
# https://en.wikipedia.org/wiki/15 - exists
# https://en.wikipedia.org/wiki/16 - exists
# https://en.wikipedia.org/wiki/17 - exists
# https://en.wikipedia.org/wiki/18 - exists
# https://en.wikipedia.org/wiki/19 - exists
# https://en.wikipedia.org/wiki/20 - exists
# https://en.wikipedia.org/wiki/21 - exists
# https://en.wikipedia.org/wiki/22 - exists
# https://en.wikipedia.org/wiki/23 - exists
# https://en.wikipedia.org/wiki/24 - exists
# https://en.wikipedia.org/wiki/25 - exists
# https://en.wikipedia.org/wiki/26 - exists
# https://en.wikipedia.org/wiki/27 - exists
# https://en.wikipedia.org/wiki/28 - exists
# https://en.wikipedia.org/wiki/29 - exists
# https://en.wikipedia.org/wiki/30 - exists
# https://en.wikipedia.org/wiki/31 - exists
# https://en.wikipedia.org/wiki/32 - exists
# https://en.wikipedia.org/wiki/33 - exists
# https://en.wikipedia.org/wiki/34 - exists
# https://en.wikipedia.org/wiki/35 - exists
# https://en.wikipedia.org/wiki/36 - exists
# https://en.wikipedia.org/wiki/37 - exists
# https://en.wikipedia.org/wiki/38 - exists
# https://en.wikipedia.org/wiki/39 - exists
# https://en.wikipedia.org/wiki/40 - exists
# https://en.wikipedia.org/wiki/41 - exists
# https://en.wikipedia.org/wiki/42 - exists
# https://en.wikipedia.org/wiki/43 - exists
# https://en.wikipedia.org/wiki/44 - exists
# https://en.wikipedia.org/wiki/45 - exists
# https://en.wikipedia.org/wiki/46 - exists
# https://en.wikipedia.org/wiki/47 - exists
# https://en.wikipedia.org/wiki/48 - exists
# https://en.wikipedia.org/wiki/49 - exists
# Without threads time: 19.579885005950928

# %%
import time
import requests
import concurrent.futures


def get_wiki_page_existence(wiki_page_url, timeout=10):
    response = requests.get(url=wiki_page_url, timeout=timeout)

    page_status = "unknown"
    if response.status_code == 200:
        page_status = "exists"
    elif response.status_code == 404:
        page_status = "does not exist"

    return wiki_page_url + " - " + page_status
wiki_page_urls = ["https://en.wikipedia.org/wiki/" + str(i) for i in range(500)]

print("Running threaded:")
threaded_start = time.time()
with concurrent.futures.ThreadPoolExecutor(12) as executor:
    futures = []
    for url in wiki_page_urls:
        futures.append(executor.submit(get_wiki_page_existence, wiki_page_url=url))
    #print(futures)
    for future in concurrent.futures.as_completed(futures):
        print(future.result())
print("Threaded time:", time.time() - threaded_start)
# Out:
# Running threaded:
# https://en.wikipedia.org/wiki/2 - exists
# https://en.wikipedia.org/wiki/4 - exists
# https://en.wikipedia.org/wiki/8 - exists
# https://en.wikipedia.org/wiki/0 - exists
# https://en.wikipedia.org/wiki/1 - exists
# https://en.wikipedia.org/wiki/3 - exists
# https://en.wikipedia.org/wiki/13 - exists
# https://en.wikipedia.org/wiki/15 - exists
# https://en.wikipedia.org/wiki/14 - exists
# https://en.wikipedia.org/wiki/16 - exists
# https://en.wikipedia.org/wiki/19 - exists
# https://en.wikipedia.org/wiki/6 - exists
# https://en.wikipedia.org/wiki/17 - exists
# https://en.wikipedia.org/wiki/226 - exists
# https://en.wikipedia.org/wiki/214 - exists
# https://en.wikipedia.org/wiki/227 - exists
# https://en.wikipedia.org/wiki/209 - exists
# https://en.wikipedia.org/wiki/228 - exists
# https://en.wikipedia.org/wiki/224 - exists
# https://en.wikipedia.org/wiki/230 - exists
# https://en.wikipedia.org/wiki/231 - exists
# https://en.wikipedia.org/wiki/232 - exists
# https://en.wikipedia.org/wiki/233 - exists
# https://en.wikipedia.org/wiki/235 - exists
# https://en.wikipedia.org/wiki/237 - exists
# https://en.wikipedia.org/wiki/239 - exists
# https://en.wikipedia.org/wiki/238 - exists
# https://en.wikipedia.org/wiki/244 - exists
# https://en.wikipedia.org/wiki/215 - exists
# https://en.wikipedia.org/wiki/242 - exists
# https://en.wikipedia.org/wiki/241 - exists
# https://en.wikipedia.org/wiki/243 - exists
# https://en.wikipedia.org/wiki/240 - exists
# https://en.wikipedia.org/wiki/245 - exists
# https://en.wikipedia.org/wiki/247 - exists
# https://en.wikipedia.org/wiki/229 - exists
# https://en.wikipedia.org/wiki/236 - exists
# https://en.wikipedia.org/wiki/246 - exists
# https://en.wikipedia.org/wiki/250 - exists
# https://en.wikipedia.org/wiki/251 - exists
# https://en.wikipedia.org/wiki/234 - exists
# https://en.wikipedia.org/wiki/254 - exists
# https://en.wikipedia.org/wiki/256 - exists
# https://en.wikipedia.org/wiki/249 - exists
# https://en.wikipedia.org/wiki/252 - exists
# https://en.wikipedia.org/wiki/248 - exists
# https://en.wikipedia.org/wiki/260 - exists
# https://en.wikipedia.org/wiki/263 - exists
# https://en.wikipedia.org/wiki/261 - exists
# https://en.wikipedia.org/wiki/255 - exists
# https://en.wikipedia.org/wiki/258 - exists
# https://en.wikipedia.org/wiki/266 - exists
# https://en.wikipedia.org/wiki/257 - exists
# https://en.wikipedia.org/wiki/262 - exists
# https://en.wikipedia.org/wiki/265 - exists
# https://en.wikipedia.org/wiki/269 - exists
# https://en.wikipedia.org/wiki/253 - exists
# https://en.wikipedia.org/wiki/273 - exists
# https://en.wikipedia.org/wiki/274 - exists
# https://en.wikipedia.org/wiki/270 - exists
# https://en.wikipedia.org/wiki/276 - exists
# https://en.wikipedia.org/wiki/277 - exists
# https://en.wikipedia.org/wiki/275 - exists
# https://en.wikipedia.org/wiki/259 - exists
# https://en.wikipedia.org/wiki/279 - exists
# https://en.wikipedia.org/wiki/280 - exists
# https://en.wikipedia.org/wiki/281 - exists
# https://en.wikipedia.org/wiki/267 - exists
# https://en.wikipedia.org/wiki/282 - exists
# https://en.wikipedia.org/wiki/283 - exists
# https://en.wikipedia.org/wiki/284 - exists
# https://en.wikipedia.org/wiki/278 - exists
# https://en.wikipedia.org/wiki/264 - exists
# https://en.wikipedia.org/wiki/287 - exists
# https://en.wikipedia.org/wiki/268 - exists
# https://en.wikipedia.org/wiki/271 - exists
# https://en.wikipedia.org/wiki/288 - exists
# https://en.wikipedia.org/wiki/291 - exists
# https://en.wikipedia.org/wiki/289 - exists
# https://en.wikipedia.org/wiki/286 - exists
# https://en.wikipedia.org/wiki/293 - exists
# https://en.wikipedia.org/wiki/292 - exists
# https://en.wikipedia.org/wiki/294 - exists
# https://en.wikipedia.org/wiki/295 - exists
# https://en.wikipedia.org/wiki/297 - exists
# https://en.wikipedia.org/wiki/296 - exists
# https://en.wikipedia.org/wiki/299 - exists
# https://en.wikipedia.org/wiki/272 - exists
# https://en.wikipedia.org/wiki/302 - exists
# https://en.wikipedia.org/wiki/304 - exists
# https://en.wikipedia.org/wiki/305 - exists
# https://en.wikipedia.org/wiki/300 - exists
# https://en.wikipedia.org/wiki/301 - exists
# https://en.wikipedia.org/wiki/298 - exists
# https://en.wikipedia.org/wiki/306 - exists
# https://en.wikipedia.org/wiki/310 - exists
# https://en.wikipedia.org/wiki/307 - exists
# https://en.wikipedia.org/wiki/311 - exists
# https://en.wikipedia.org/wiki/308 - exists
# https://en.wikipedia.org/wiki/313 - exists
# https://en.wikipedia.org/wiki/312 - exists
# https://en.wikipedia.org/wiki/314 - exists
# https://en.wikipedia.org/wiki/290 - exists
# https://en.wikipedia.org/wiki/309 - exists
# https://en.wikipedia.org/wiki/316 - exists
# https://en.wikipedia.org/wiki/320 - exists
# https://en.wikipedia.org/wiki/303 - exists
# https://en.wikipedia.org/wiki/319 - exists
# https://en.wikipedia.org/wiki/322 - exists
# https://en.wikipedia.org/wiki/323 - exists
# https://en.wikipedia.org/wiki/324 - exists
# https://en.wikipedia.org/wiki/315 - exists
# https://en.wikipedia.org/wiki/326 - exists
# https://en.wikipedia.org/wiki/321 - exists
# https://en.wikipedia.org/wiki/327 - exists
# https://en.wikipedia.org/wiki/325 - exists
# https://en.wikipedia.org/wiki/317 - exists
# https://en.wikipedia.org/wiki/330 - exists
# https://en.wikipedia.org/wiki/318 - exists
# https://en.wikipedia.org/wiki/329 - exists
# https://en.wikipedia.org/wiki/328 - exists
# https://en.wikipedia.org/wiki/285 - exists
# https://en.wikipedia.org/wiki/332 - exists
# https://en.wikipedia.org/wiki/334 - exists
# https://en.wikipedia.org/wiki/333 - exists
# https://en.wikipedia.org/wiki/336 - exists
# https://en.wikipedia.org/wiki/337 - exists
# https://en.wikipedia.org/wiki/342 - exists
# https://en.wikipedia.org/wiki/340 - exists
# https://en.wikipedia.org/wiki/344 - exists
# https://en.wikipedia.org/wiki/335 - exists
# https://en.wikipedia.org/wiki/345 - exists
# https://en.wikipedia.org/wiki/343 - exists
# https://en.wikipedia.org/wiki/347 - exists
# https://en.wikipedia.org/wiki/350 - exists
# https://en.wikipedia.org/wiki/341 - exists
# https://en.wikipedia.org/wiki/351 - exists
# https://en.wikipedia.org/wiki/348 - exists
# https://en.wikipedia.org/wiki/353 - exists
# https://en.wikipedia.org/wiki/338 - exists
# https://en.wikipedia.org/wiki/339 - exists
# https://en.wikipedia.org/wiki/355 - exists
# https://en.wikipedia.org/wiki/357 - exists
# https://en.wikipedia.org/wiki/331 - exists
# https://en.wikipedia.org/wiki/349 - exists
# https://en.wikipedia.org/wiki/346 - exists
# https://en.wikipedia.org/wiki/356 - exists
# https://en.wikipedia.org/wiki/361 - exists
# https://en.wikipedia.org/wiki/358 - exists
# https://en.wikipedia.org/wiki/362 - exists
# https://en.wikipedia.org/wiki/363 - exists
# https://en.wikipedia.org/wiki/364 - exists
# https://en.wikipedia.org/wiki/360 - exists
# https://en.wikipedia.org/wiki/367 - exists
# https://en.wikipedia.org/wiki/359 - exists
# https://en.wikipedia.org/wiki/366 - exists
# https://en.wikipedia.org/wiki/370 - exists
# https://en.wikipedia.org/wiki/369 - exists
# https://en.wikipedia.org/wiki/368 - exists
# https://en.wikipedia.org/wiki/376 - exists
# https://en.wikipedia.org/wiki/352 - exists
# https://en.wikipedia.org/wiki/375 - exists
# https://en.wikipedia.org/wiki/374 - exists
# https://en.wikipedia.org/wiki/377 - exists
# https://en.wikipedia.org/wiki/354 - exists
# https://en.wikipedia.org/wiki/372 - exists
# https://en.wikipedia.org/wiki/379 - exists
# https://en.wikipedia.org/wiki/380 - exists
# https://en.wikipedia.org/wiki/373 - exists
# https://en.wikipedia.org/wiki/378 - exists
# https://en.wikipedia.org/wiki/383 - exists
# https://en.wikipedia.org/wiki/365 - exists
# https://en.wikipedia.org/wiki/384 - exists
# https://en.wikipedia.org/wiki/382 - exists
# https://en.wikipedia.org/wiki/391 - exists
# https://en.wikipedia.org/wiki/389 - exists
# https://en.wikipedia.org/wiki/371 - exists
# https://en.wikipedia.org/wiki/392 - exists
# https://en.wikipedia.org/wiki/385 - exists
# https://en.wikipedia.org/wiki/393 - exists
# https://en.wikipedia.org/wiki/386 - exists
# https://en.wikipedia.org/wiki/381 - exists
# https://en.wikipedia.org/wiki/388 - exists
# https://en.wikipedia.org/wiki/394 - exists
# https://en.wikipedia.org/wiki/397 - exists
# https://en.wikipedia.org/wiki/396 - exists
# https://en.wikipedia.org/wiki/398 - exists
# https://en.wikipedia.org/wiki/387 - exists
# https://en.wikipedia.org/wiki/402 - exists
# https://en.wikipedia.org/wiki/403 - exists
# https://en.wikipedia.org/wiki/406 - exists
# https://en.wikipedia.org/wiki/390 - exists
# https://en.wikipedia.org/wiki/405 - exists
# https://en.wikipedia.org/wiki/400 - exists
# https://en.wikipedia.org/wiki/409 - exists
# https://en.wikipedia.org/wiki/408 - exists
# https://en.wikipedia.org/wiki/399 - exists
# https://en.wikipedia.org/wiki/410 - exists
# https://en.wikipedia.org/wiki/413 - exists
# https://en.wikipedia.org/wiki/407 - exists
# https://en.wikipedia.org/wiki/414 - exists
# https://en.wikipedia.org/wiki/395 - exists
# https://en.wikipedia.org/wiki/416 - exists
# https://en.wikipedia.org/wiki/404 - exists
# https://en.wikipedia.org/wiki/419 - exists
# https://en.wikipedia.org/wiki/417 - exists
# https://en.wikipedia.org/wiki/412 - exists
# https://en.wikipedia.org/wiki/411 - exists
# https://en.wikipedia.org/wiki/415 - exists
# https://en.wikipedia.org/wiki/418 - exists
# https://en.wikipedia.org/wiki/421 - exists
# https://en.wikipedia.org/wiki/401 - exists
# https://en.wikipedia.org/wiki/423 - exists
# https://en.wikipedia.org/wiki/422 - exists
# https://en.wikipedia.org/wiki/424 - exists
# https://en.wikipedia.org/wiki/430 - exists
# https://en.wikipedia.org/wiki/427 - exists
# https://en.wikipedia.org/wiki/431 - exists
# https://en.wikipedia.org/wiki/426 - exists
# https://en.wikipedia.org/wiki/429 - exists
# https://en.wikipedia.org/wiki/420 - exists
# https://en.wikipedia.org/wiki/433 - exists
# https://en.wikipedia.org/wiki/434 - exists
# https://en.wikipedia.org/wiki/435 - exists
# https://en.wikipedia.org/wiki/425 - exists
# https://en.wikipedia.org/wiki/432 - exists
# https://en.wikipedia.org/wiki/436 - exists
# https://en.wikipedia.org/wiki/437 - exists
# https://en.wikipedia.org/wiki/439 - exists
# https://en.wikipedia.org/wiki/438 - exists
# https://en.wikipedia.org/wiki/428 - exists
# https://en.wikipedia.org/wiki/446 - exists
# https://en.wikipedia.org/wiki/443 - exists
# https://en.wikipedia.org/wiki/444 - exists
# https://en.wikipedia.org/wiki/440 - exists
# https://en.wikipedia.org/wiki/445 - exists
# https://en.wikipedia.org/wiki/448 - exists
# https://en.wikipedia.org/wiki/449 - exists
# https://en.wikipedia.org/wiki/447 - exists
# https://en.wikipedia.org/wiki/455 - exists
# https://en.wikipedia.org/wiki/441 - exists
# https://en.wikipedia.org/wiki/454 - exists
# https://en.wikipedia.org/wiki/457 - exists
# https://en.wikipedia.org/wiki/458 - exists
# https://en.wikipedia.org/wiki/453 - exists
# https://en.wikipedia.org/wiki/450 - exists
# https://en.wikipedia.org/wiki/451 - exists
# https://en.wikipedia.org/wiki/459 - exists
# https://en.wikipedia.org/wiki/461 - exists
# https://en.wikipedia.org/wiki/456 - exists
# https://en.wikipedia.org/wiki/465 - exists
# https://en.wikipedia.org/wiki/452 - exists
# https://en.wikipedia.org/wiki/442 - exists
# https://en.wikipedia.org/wiki/467 - exists
# https://en.wikipedia.org/wiki/469 - exists
# https://en.wikipedia.org/wiki/468 - exists
# https://en.wikipedia.org/wiki/464 - exists
# https://en.wikipedia.org/wiki/462 - exists
# https://en.wikipedia.org/wiki/470 - exists
# https://en.wikipedia.org/wiki/463 - exists
# https://en.wikipedia.org/wiki/466 - exists
# https://en.wikipedia.org/wiki/472 - exists
# https://en.wikipedia.org/wiki/477 - exists
# https://en.wikipedia.org/wiki/479 - exists
# https://en.wikipedia.org/wiki/475 - exists
# https://en.wikipedia.org/wiki/480 - exists
# https://en.wikipedia.org/wiki/478 - exists
# https://en.wikipedia.org/wiki/473 - exists
# https://en.wikipedia.org/wiki/482 - exists
# https://en.wikipedia.org/wiki/481 - exists
# https://en.wikipedia.org/wiki/476 - exists
# https://en.wikipedia.org/wiki/460 - exists
# https://en.wikipedia.org/wiki/474 - exists
# https://en.wikipedia.org/wiki/485 - exists
# https://en.wikipedia.org/wiki/484 - exists
# https://en.wikipedia.org/wiki/483 - exists
# https://en.wikipedia.org/wiki/487 - exists
# https://en.wikipedia.org/wiki/486 - exists
# https://en.wikipedia.org/wiki/490 - exists
# https://en.wikipedia.org/wiki/492 - exists
# https://en.wikipedia.org/wiki/491 - exists
# https://en.wikipedia.org/wiki/471 - exists
# https://en.wikipedia.org/wiki/494 - exists
# https://en.wikipedia.org/wiki/493 - exists
# https://en.wikipedia.org/wiki/488 - exists
# https://en.wikipedia.org/wiki/489 - exists
# https://en.wikipedia.org/wiki/499 - exists
# https://en.wikipedia.org/wiki/498 - exists
# https://en.wikipedia.org/wiki/495 - exists
# https://en.wikipedia.org/wiki/497 - exists
# https://en.wikipedia.org/wiki/496 - exists
# Threaded time: 30.54166316986084
