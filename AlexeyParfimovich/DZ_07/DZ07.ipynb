# %% [markdown]
# ## Группа DS03-onl
#
# Студент Парфимович Алексей
#
# ## Домашнее задание №7

# %%
import os
import time
import string
import shutil
import pathlib
import requests
import multiprocessing as mp
import concurrent.futures as cf
